# %% [markdown]
# #Basic data analysis using Pandas

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-bfdb2657-f397-447e-89cb-c194f510e270" name="files[]" multiple disabled />
#      <output id="result-bfdb2657-f397-447e-89cb-c194f510e270">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving impacts.csv to impacts.csv
# ...

# %%
import pandas as pd

# %%
data = pd.read_csv('impacts.csv', delimiter=',')

# %%
print(data.shape)
# Out:
# (683, 11)

# %%
print(data.columns)
# Out:
# Index(['Object Name', 'Period Start', 'Period End', 'Possible Impacts',
#        'Cumulative Impact Probability', 'Asteroid Velocity',
#        'Asteroid Magnitude', 'Asteroid Diameter (km)',
#        'Cumulative Palermo Scale', 'Maximum Palermo Scale',
#        'Maximum Torino Scale'],
#       dtype='object')

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 683 entries, 0 to 682
# Data columns (total 11 columns):
# Object Name                      683 non-null object
# Period Start                     683 non-null int64
# Period End                       683 non-null int64
# Possible Impacts                 683 non-null int64
# Cumulative Impact Probability    683 non-null float64
# Asteroid Velocity                683 non-null float64
# Asteroid Magnitude               683 non-null float64
# Asteroid Diameter (km)           683 non-null float64
# Cumulative Palermo Scale         683 non-null float64
# Maximum Palermo Scale            683 non-null float64
# Maximum Torino Scale             683 non-null object
# dtypes: float64(6), int64(3), object(2)
# memory usage: 58.8+ KB
# None

# %%
data.head()
# Out:
#   Object Name  Period Start  ...  Maximum Palermo Scale  Maximum Torino Scale
# 0    2006 WP1          2017  ...                  -8.31                     0
# 1     2013 YB          2017  ...                  -6.96                     0
# 2     2008 US          2017  ...                  -6.87                     0
# 3  2010 VR139          2017  ...                  -6.95                     0
# 4  2015 ME131          2017  ...                  -4.30                     0
#
# [5 rows x 11 columns]

# %%
data.isnull().values.any()

# If there are blank cells
# data = data.dropna()

data = data.fillna(0)

# %%
data.describe()
# Out:
#        Period Start  ...  Maximum Palermo Scale
# count    683.000000  ...             683.000000
# mean    2062.573939  ...              -6.804012
# std       43.501694  ...               1.476135
# min     2017.000000  ...             -11.000000
# 25%     2034.000000  ...              -7.790000
# 50%     2061.000000  ...              -6.790000
# 75%     2085.000000  ...              -5.865000
# max     2880.000000  ...              -1.420000
#
# [8 rows x 9 columns]

# %%
data.describe().T
# Out:
#                                count         mean  ...          75%       max
# Period Start                   683.0  2062.573939  ...  2085.000000  2880.000
# Period End                     683.0  2099.680820  ...  2114.000000  2880.000
# Possible Impacts               683.0    43.348463  ...    29.000000  1144.000
# Cumulative Impact Probability  683.0     0.000154  ...     0.000015     0.065
# Asteroid Velocity              683.0    11.462577  ...    14.810000    39.470
# Asteroid Magnitude             683.0    26.158272  ...    27.800000    31.600
# Asteroid Diameter (km)         683.0     0.049378  ...     0.033000     2.579
# Cumulative Palermo Scale       683.0    -6.511552  ...    -5.490000    -1.420
# Maximum Palermo Scale          683.0    -6.804012  ...    -5.865000    -1.420
#
# [9 rows x 8 columns]

# %%
data['Possible Impacts'].value_counts()
# Out:
# 1      130
# 2       74
# 3       48
# 4       37
# 5       28
#       ...
# 184      1
# 186      1
# 187      1
# 192      1
# 84       1
# Name: Possible Impacts, Length: 140, dtype: int64

# %%
data.sort_values(by='Possible Impacts', ascending=False).head()
# Out:
#    Object Name  Period Start  ...  Maximum Palermo Scale  Maximum Torino Scale
# 22   2008 EM68          2017  ...                  -5.65                     0
# 18   2009 VZ39          2017  ...                  -7.61                     0
# 19   2014 JT79          2017  ...                  -7.31                     0
# 35   2011 CF66          2018  ...                  -7.18                     0
# 72   2016 QY84          2020  ...                  -8.32                     0
#
# [5 rows x 11 columns]

# %%
data['Possible Impacts'].mean()
# Out:
# 43.348462664714496

# %%
from sklearn.utils import shuffle
data = shuffle(data)
data.head()
# Out:
#     Object Name  Period Start  ...  Maximum Palermo Scale  Maximum Torino Scale
# 587  2005 GV190          2099  ...                  -6.84                     0
# 337     2008 CJ          2061  ...                  -7.50                     0
# 230   2006 HX57          2045  ...                  -5.63                     0
# 357   2007 RC20          2065  ...                  -9.70                     0
# 515   2004 BN41          2086  ...                  -7.07                     0
#
# [5 rows x 11 columns]

# %%
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = ((20,20))
data.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f88a4945c88>,
# ...
#       dtype=object)

# %%
plt.rcParams.update(plt.rcParamsDefault)
plt.scatter(data['Possible Impacts'], data['Asteroid Velocity'])
plt.xlabel('Possible Impacts')
plt.ylabel('Asteroid Velocity')
plt.show()

# %%
import seaborn as sns
correlation = data.corr()
sns.heatmap(correlation, xticklabels=correlation.columns, yticklabels=correlation.columns)
